# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("budget-allocation.csv")
data
# Out:
#                Province     Year Allocated Budget (Rs. In Millions)  \
# 0                Punjab  2013-14                                 36
# 1                Punjab  2006-07                                 50
# 2                Punjab  2006-07                                 50
# 3                Punjab  2006-07                                 50
# 4                Punjab  2007-08                                 82
# ..                  ...      ...                                ...
# 304  Khyber Pakhtunkhwa  2018-19                                472
# 305  Khyber Pakhtunkhwa  2018-19                                145
# 306  Khyber Pakhtunkhwa  2018-19                           11863.47
# 307  Khyber Pakhtunkhwa  2018-19                            1638.92
# 308  Khyber Pakhtunkhwa  2018-19                                400
#
#                Sector/Sub-Sector  Population  Normalized
# 0    Auqaf and Religious Affairs  98223000.0    0.036651
# ...

# %%
data['Allocated Budget (Rs. In Millions)'] = pd.to_numeric(data['Allocated Budget (Rs. In Millions)'])
# Out:
# <ipython-input-6-40a6d1419987>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Allocated Budget (Rs. In Millions)'] = pd.to_numeric(data['Allocated Budget (Rs. In Millions)'])

# %%
data['Province'] = data['Province'].astype('category')
# Out:
# <ipython-input-7-55006030a18f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Province'] = data['Province'].astype('category')

# %%
data['Sector/Sub-Sector'] = data['Sector/Sub-Sector'].astype('category')
data['Sector/Sub-Sector']
# Out:
# <ipython-input-8-d35bd802883c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Sector/Sub-Sector'] = data['Sector/Sub-Sector'].astype('category')
# 0      Auqaf and Religious Affairs
# 1                             Food
# 2                             Food
# 3      Auqaf and Religious Affairs
# 4      Auqaf and Religious Affairs
#                   ...
# 304                           Food
# 305         Information Technology
# 306                         Health
# 307                     Industries
# 308    Auqaf and Religious Affairs
# Name: Sector/Sub-Sector, Length: 260, dtype: category
# ...

# %%
data['Province']
# Out:
# 0                  Punjab
# 1                  Punjab
# 2                  Punjab
# 3                  Punjab
# 4                  Punjab
#               ...
# 304    Khyber Pakhtunkhwa
# 305    Khyber Pakhtunkhwa
# 306    Khyber Pakhtunkhwa
# 307    Khyber Pakhtunkhwa
# 308    Khyber Pakhtunkhwa
# Name: Province, Length: 260, dtype: category
# Categories (4, object): ['Balochistan', 'Khyber Pakhtunkhwa', 'Punjab', 'Sindh']

# %%
data.shape
# Out:
# (259, 6)

# %%
data.isna().sum()
# Out:
# Province                               0
# Year                                   0
# Allocated Budget (Rs. In Millions)     0
# Sector/Sub-Sector                      0
# Population                            48
# Normalized                            49
# dtype: int64

# %%
data=data.dropna()

# %%
data.isna().sum()
# Out:
# Province                              0
# Year                                  0
# Allocated Budget (Rs. In Millions)    0
# Sector/Sub-Sector                     0
# Population                            0
# Normalized                            0
# dtype: int64

# %% [markdown]
# # Population in each Province

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Province', y='Population', data=data)
# Out:
# <AxesSubplot:xlabel='Province', ylabel='Population'>

# %% [markdown]
# # Budget Allocation to different sectors

# %%
plt.figure(figsize=(15,8))
sns.barplot(x='Sector/Sub-Sector', y='Allocated Budget (Rs. In Millions)', data=data)
# Out:
# <AxesSubplot:xlabel='Sector/Sub-Sector', ylabel='Allocated Budget (Rs. In Millions)'>

# %% [markdown]
# # Total Budget Allocated to each province so far

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Province', y='Allocated Budget (Rs. In Millions)', data=data, palette=['green','blue','orange','yellow'])
sns.set_palette("Paired")

# %% [markdown]
# # **Distribution of The Budget For Top 10 Ministries**

# %%
data = data.sort_values(by='Allocated Budget (Rs. In Millions)',ascending=False)
data.head(10)
# Out:
#                Province     Year  Allocated Budget (Rs. In Millions)  \
# 291              Punjab  2015-16                            55564.00
# 289              Punjab  2014-15                            48310.00
# 285              Punjab  2016-17                            45000.00
# 282              Punjab  2016-17                            43836.00
# 273              Punjab  2014-15                            31070.00
# 269              Punjab  2015-16                            30725.00
# 279              Punjab  2008-09                            30129.00
# 177  Khyber Pakhtunkhwa  2013-14                            29798.97
# 296  Khyber Pakhtunkhwa  2017-18                            27033.53
# 265              Punjab  2013-14                            26890.00
#
#     Sector/Sub-Sector   Population  Normalized
# 291         Education  101391000.0   54.801708
# 289         Education   99794000.0   48.409724
# 285            Health  103013000.0   43.683807
# ...

# %%
new_data=data.head(10)
df = new_data["Allocated Budget (Rs. In Millions)"]
labels = new_data["Sector/Sub-Sector"]
plt.figure(figsize=(10,9))
plt.pie(df, labels=labels, autopct='%1.1f%%', startangle=45, pctdistance=0.7, shadow =True)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Distribution of The Budget For Top 10 Sectors", fontweight='bold')
plt.show()

# %% [markdown]
# # Distribution of The Budget For Last 10 Ministries

# %%
data = data.sort_values(by='Allocated Budget (Rs. In Millions)',ascending=True)
new_data = data.head(10)
new_data
# Out:
#         Province     Year  Allocated Budget (Rs. In Millions)  \
# 274  Balochistan  2016-17                                0.00
# 211  Balochistan  2014-15                                0.00
# 146  Balochistan  2011-12                                0.00
# 243  Balochistan  2015-16                                0.00
# 253  Balochistan  2015-16                                8.69
# 283  Balochistan  2016-17                               16.50
# 144  Balochistan  2011-12                               21.53
# 142  Balochistan  2011-12                               30.00
# 0         Punjab  2013-14                               36.00
# 151  Balochistan  2011-12                               38.05
#
#                Sector/Sub-Sector  Population  Normalized
# 274                         Food  11045000.0    0.000000
# 211                         Food  10375000.0    0.000000
# 146          Women's Development   9162000.0    0.000000
# ...

# %%
df = new_data["Allocated Budget (Rs. In Millions)"]
labels = new_data["Sector/Sub-Sector"]
plt.figure(figsize=(10,9))
plt.pie(df, labels=labels, autopct='%1.1f%%', startangle=0, pctdistance=0.7, shadow =True)
central_circle = plt.Circle((0, 0), 0.8, color='white') #change the 0.8 to see changes to the circle
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Distribution of The Budget For Last 10 Ministries", fontweight='bold')
plt.show()

# %%
data.plot.bar(x='Sector/Sub-Sector', y='Allocated Budget (Rs. In Millions)',figsize=(18,8))
plt.title("Distribution of The Budget For Last 10 Ministries", fontweight='bold')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.columns
# Out:
# Index(['Province', 'Year', 'Allocated Budget (Rs. In Millions)',
#        'Sector/Sub-Sector', 'Population', 'Normalized'],
#       dtype='object')

# %% [markdown]
# **You can plot only the last 10 ministries**

# %%
new_data.plot.bar(x='Sector/Sub-Sector', y='Allocated Budget (Rs. In Millions)',figsize=(18,8))
plt.title("Distribution of The Budget For Last 10 Ministries", fontweight='bold')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(15,8))
sns.barplot(x = 'Province', y = 'Allocated Budget (Rs. In Millions)', data = data, hue='Year')
# Out:
# <AxesSubplot:xlabel='Province', ylabel='Allocated Budget (Rs. In Millions)'>

# %%
plt.figure(figsize=(15,8))
sns.barplot(x = 'Province', y = 'Allocated Budget (Rs. In Millions)', data = data, hue='Sector/Sub-Sector')
# Out:
# <AxesSubplot:xlabel='Province', ylabel='Allocated Budget (Rs. In Millions)'>
