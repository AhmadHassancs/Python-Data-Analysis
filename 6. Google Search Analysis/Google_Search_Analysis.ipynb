# %% [markdown]
# We will use Python to analyze certain keywords.
#
# We will:
#
#
# *   Find the top 10 countries where a particular keyword is being searched the most.
# *   Visualise the top 10 countries using Python Matplotlib library
# * Visualise the trend of the keyword search over the years

# %% [markdown]
# Google doesn’t give much access to the data about daily search queries, but another application of google known as Google Trends can be used for the task of Google search analysis. Google Trends provides an API that can be used to analyze the daily searches on Google. This API is known as pytrends, you can easily install it in your systems by using the pip command; pip install pytrends.

# %% [markdown]
# #**Installation**

# %%
pip install pytrends

# %% [markdown]
# #**Import The Necessary Libraries**

# %%
import pandas as pd
import pytrends
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %% [markdown]
# #**Now Let's Find Countries Where Certain Keywords Are Searched The Most**

# %%
#add your keyword here
trends.build_payload(kw_list=['machine learning']) 
data = trends.interest_by_region()

data = data.sort_values(by="machine learning", ascending=False) 
data = data.head(20)

print(data)
# Out:
#                       machine learning
# geoName
# China                              100
# Singapore                           39
# Ethiopia                            31
# St. Helena                          30
# India                               28
# Hong Kong                           24
# South Korea                         23
# Nepal                               19
# Pakistan                            18
# Tunisia                             17
# Bangladesh                          17
# Israel                              16
# Switzerland                         15
# Ireland                             15
# Sri Lanka                           14
# Canada                              14
# Denmark                             13
# Kenya                               13
# United Arab Emirates                13
# Sweden                              12

# %%
data.reset_index().plot(x="geoName", y="machine learning", figsize=(15,10), kind="bar", color = 'green')
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['machine learning'])

data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 10))

data['machine learning'].plot()

plt.title("Total Google Searches for keyword: 'Machine Learning'", fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')

plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# #**Historical Interest Overtime**

# %%
keywrd_list = ["pakistan"]
data = trends.get_historical_interest(keywrd_list, year_start=2021, month_start=1, 
                                      day_start=1, hour_start=0, year_end=2021, month_end=3, 
                                      day_end=1, hour_end=0, cat=0, geo='', gprop='', sleep=0)

data = data.sort_values(by="pakistan", ascending=False) 
data = data.head(30)

print(data)
# Out:
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=5)
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=5)
# HTTPSConnectionPool(host='trends.google.com', port=443): Read timed out. (read timeout=5)
#                      pakistan  isPartial
# date
# 2021-01-03 05:00:00       100      False
# 2021-01-29 06:00:00       100      False
# 2021-02-20 07:00:00       100      False
# 2021-02-08 08:00:00       100      False
# 2021-01-28 05:00:00       100      False
# 2021-02-27 07:00:00       100      False
# 2021-02-27 06:00:00       100      False
# 2021-02-20 06:00:00        99      False
# 2021-02-27 08:00:00        98      False
# 2021-01-05 05:00:00        97      False
# 2021-02-21 08:00:00        96      False
# 2021-02-27 09:00:00        96      False
# 2021-02-27 10:00:00        96      False
# 2021-02-28 07:00:00        95      False
# 2021-02-21 07:00:00        95      False
# ...

# %%
data.reset_index().plot(x="date", y="pakistan", 
                        figsize=(15,6), kind="bar", color='green')
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['python programming'])

data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 6))

data['python programming'].plot()
plt.title("Total Google Searches for keyword: 'Python Programming' overtime", fontweight='bold')

plt.xlabel('Year')
plt.ylabel('Total Count')

plt.show()
